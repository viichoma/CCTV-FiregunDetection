# %% [markdown]
# # **Criar e importar a pasta do Google Drive**

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Voltar a pasta content

# %%
# !cd /content

# %% [markdown]
# # **Clonar repositório com todos os dados**

# %%
# !git clone https://github.com/viichoma/CCTV-FiregunDetection.git
# Out:
# Cloning into 'CCTV-FiregunDetection'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 14 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 6.47 MiB | 12.61 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %% [markdown]
# Voltar a pasta content

# %% [markdown]
# # **Clonar repositório com todas os requisitos do YoloV10**

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20332, done.
# remote: Counting objects: 100% (2446/2446), done.
# remote: Compressing objects: 100% (250/250), done.
# remote: Total 20332 (delta 2317), reused 2197 (delta 2196), pack-reused 17886 (from 1)
# Receiving objects: 100% (20332/20332), 11.14 MiB | 14.65 MiB/s, done.
# Resolving deltas: 100% (14337/14337), done.

# %% [markdown]
# Mudar para a pasta yolov10

# %%
cd yolov10
# Out:
# /content/yolov10

# %% [markdown]
# Instalar os requisitos do yolov10

# %%
pip install .
# Out:
# Processing /content/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=731421 sha256=2648cfdd70d967c9eee1272f5f76113fb836403ab9536692c5c5be382c3617b8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l8hd4zo_/wheels/51/93/e8/22d2e815ced343915c15d86b2a00d95eb0a997d012527fbea7
# Successfully built ultralytics
# ...

# %% [markdown]
# Voltar a pasta content

# %%
cd /content
# Out:
# /content

# %%
pip install -U albumentations
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.9/227.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.7/632.7 kB 14.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.19
#     Uninstalling albucore-0.0.19:
#       Successfully uninstalled albucore-0.0.19
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.20
#     Uninstalling albumentations-1.4.20:
#       Successfully uninstalled albumentations-1.4.20
# ...

# %%
pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 kB 13.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
#       Successfully uninstalled ultralytics-8.1.34
# ...

# %% [markdown]
# # **Comando para treinar o modelo**
#
# ```
# # !yolo task={tarefa} mode={modo} epochs={passadas no DataSet} batch={n° de instancias} plots=True model={caminho do modelo} data={caminho do yaml}/custom_data.yaml project={local onde vai ser salvo}
# ```

# %%
# !yolo task=detect mode=train epochs=50 batch=16 plots=True model=/content/CCTV-FiregunDetection/yolov10n.pt data=/content/CCTV-FiregunDetection/custom_data.yaml project='Projetof2' name=Fold2t
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
# !mv /content/Projetof2 /content/drive/MyDrive

# %% [markdown]
# # **Comando para detectar e prever com dados de confiança acima de 25%**

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/TG/Pesos/Dataset/weights/best.pt source=/content/drive/MyDrive/TG/videos/CAMERA.mp4 project=/content/drive/MyDrive format=mp4
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv10n summary (fused): 285 layers, 2,695,196 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/2399) /content/drive/MyDrive/TG/videos/CAMERA.mp4: 384x640 (no detections), 160.0ms
# video 1/1 (frame 2/2399) /content/drive/MyDrive/TG/videos/CAMERA.mp4: 384x640 (no detections), 146.8ms
# video 1/1 (frame 3/2399) /content/drive/MyDrive/TG/videos/CAMERA.mp4: 384x640 (no detections), 161.6ms
# video 1/1 (frame 4/2399) /content/drive/MyDrive/TG/videos/CAMERA.mp4: 384x640 (no detections), 149.9ms
# video 1/1 (frame 5/2399) /content/drive/MyDrive/TG/videos/CAMERA.mp4: 384x640 (no detections), 146.1ms
# video 1/1 (frame 6/2399) /content/drive/MyDrive/TG/videos/CAMERA.mp4: 384x640 (no detections), 145.4ms
# video 1/1 (frame 7/2399) /content/drive/MyDrive/TG/videos/CAMERA.mp4: 384x640 (no detections), 144.7ms
# ...

# %%
# !ffmpeg -i /content/drive/MyDrive/predict5/Camera.avi -c:v libx264 /content/drive/MyDrive/predict5/Camera.mp4
